# %% [markdown]
# # Train Model

# %% [markdown]
# **INPUT**: "./data/1finalDataset.csv"
#
# **OUTPUT**: Outputs the XGBoostModels "./models/best_xgb_model.json"

# %% [markdown]
# In this notebook, we take the final dataset (which contains all the tennis statistics), and we train several models with it (Random Forest, XGBoost, Neural Net). Then, we will save the best models to the models folder.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn import tree
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from tensorflow import keras
from tensorflow.keras import layers
pd.set_option('display.max_columns', None)

# %%
final_dataset = pd.read_csv("data/tennis_atp-master/1finalDataset.csv")
final_dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 final_dataset = pd.read_csv("./data/1finalDataset.csv")
#       2 final_dataset
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/1finalDataset.csv'

# %% [markdown]
# ## Split Training vs Testing Data

# %% [markdown]
# We'll shuffle the data, and do a 85% split between training and testing data.

# %%
# Convert data to numpy (exclude the first 5k matches, since ELO hasn't been properly calculated yet)
data = final_dataset.to_numpy(dtype=object)[5000:,:]
np.random.shuffle(data)

# Split the data using an 85% split between training and testing
split = 0.85
value = round(split*len(data))

data_train = data[:value,:]
data_test = data[value:,:]

print("Training Data: "+str(data_train.shape))
print("Testing Data: "+str(data_test.shape))
# Out:
# Training Data: (76819, 68)
# Testing Data: (13556, 68)

# %% [markdown]
# We need to map the result column to string values (since that's what the sklearn library requires I'm pretty sure)

# %%
# Define several mappers
mapper = np.vectorize(lambda x: "Player 2 Wins" if x == 0 else "Player 1 Wins")
reverse_mapper = np.vectorize(lambda x: 0 if x == "Player 2 Wins" else 1)

# Training data
x_train = data_train[:,:-1]
y_pred_train = mapper(data_train[:,-1:]).squeeze()

# Testing data
x_test = data_test[:,:-1]
y_pred_test = mapper(data_test[:,-1:]).squeeze()

# %% [markdown]
# ## Train Models

# %% [markdown]
# ### Train Simple Decision Tree

# %% [markdown]
# We can start by training a really simple decision tree (max_depth=4) to see how good it is.

# %%
# Instantiate a Decision Tree
decision_sklearn = DecisionTreeClassifier(max_depth=4)
decision_sklearn = decision_sklearn.fit(x_train, y_pred_train)

# Make predictions and test accuracy
predictions_train = decision_sklearn.predict(x_train)
predictions_test = decision_sklearn.predict(x_test)
print("Train Accuracy: "+str(accuracy_score(y_pred_train, predictions_train)))
print("Test Accuracy: "+str(accuracy_score(y_pred_test, predictions_test)))
# Out:
# Train Accuracy: 0.65740246553587
# Test Accuracy: 0.6535851283564473

# %%
text_representation = tree.export_text(decision_sklearn, feature_names=final_dataset.columns[:-1])
print(text_representation)
# Out:
# |--- ELO_DIFF <= 4.66
# |   |--- ELO_DIFF <= -110.91
# |   |   |--- ELO_DIFF <= -229.70
# |   |   |   |--- ELO_DIFF <= -348.35
# |   |   |   |   |--- class: Player 2 Wins
# |   |   |   |--- ELO_DIFF >  -348.35
# |   |   |   |   |--- class: Player 2 Wins
# |   |   |--- ELO_DIFF >  -229.70
# |   |   |   |--- ELO_SURFACE_DIFF <= -81.19
# |   |   |   |   |--- class: Player 2 Wins
# |   |   |   |--- ELO_SURFACE_DIFF >  -81.19
# |   |   |   |   |--- class: Player 2 Wins
# |   |--- ELO_DIFF >  -110.91
# |   |   |--- ATP_RANK_DIFF <= 162.50
# |   |   |   |--- ELO_SURFACE_DIFF <= -44.50
# |   |   |   |   |--- class: Player 2 Wins
# |   |   |   |--- ELO_SURFACE_DIFF >  -44.50
# |   |   |   |   |--- class: Player 2 Wins
# |   |   |--- ATP_RANK_DIFF >  162.50
# |   |   |   |--- P_1ST_IN_LAST_3_DIFF <= -2.66
# |   |   |   |   |--- class: Player 2 Wins
# |   |   |   |--- P_1ST_IN_LAST_3_DIFF >  -2.66
# |   |   |   |   |--- class: Player 2 Wins
# |--- ELO_DIFF >  4.66
# |   |--- ELO_DIFF <= 150.49
# |   |   |--- ELO_SURFACE_DIFF <= 61.68
# |   |   |   |--- ATP_RANK_DIFF <= -54.50
# |   |   |   |   |--- class: Player 1 Wins
# |   |   |   |--- ATP_RANK_DIFF >  -54.50
# |   |   |   |   |--- class: Player 1 Wins
# |   |   |--- ELO_SURFACE_DIFF >  61.68
# |   |   |   |--- AGE_DIFF <= 3.95
# |   |   |   |   |--- class: Player 1 Wins
# |   |   |   |--- AGE_DIFF >  3.95
# |   |   |   |   |--- class: Player 1 Wins
# |   |--- ELO_DIFF >  150.49
# |   |   |--- ELO_DIFF <= 310.90
# |   |   |   |--- ELO_SURFACE_DIFF <= 8.26
# |   |   |   |   |--- class: Player 1 Wins
# |   |   |   |--- ELO_SURFACE_DIFF >  8.26
# |   |   |   |   |--- class: Player 1 Wins
# |   |   |--- ELO_DIFF >  310.90
# |   |   |   |--- ELO_SURFACE_DIFF <= 145.02
# |   |   |   |   |--- class: Player 1 Wins
# |   |   |   |--- ELO_SURFACE_DIFF >  145.02
# |   |   |   |   |--- class: Player 1 Wins

# %% [markdown]
# As we can see in the output, it seems like it's only taking ELO into account, which we don't really want (since otherwise we could just predict using ELO alone).

# %% [markdown]
# Let's see if a Random Forest works better :)

# %% [markdown]
# ### Train Random Forest

# %% [markdown]
# We start by training a pretty big random forest (n_estimators=500)

# %%
# Instantiate a Random Forsest
forest_sklearn = RandomForestClassifier(n_estimators=500, max_depth=10, max_features="sqrt", bootstrap=True)
forest_sklearn = forest_sklearn.fit(x_train, y_pred_train)

# Make predictions and test accuracy
predictions_train = forest_sklearn.predict(x_train)
predictions_test = forest_sklearn.predict(x_test)
print("Train Accuracy: "+str(accuracy_score(y_pred_train, predictions_train)))
print("Test Accuracy: "+str(accuracy_score(y_pred_test, predictions_test)))
# Out:
# Train Accuracy: 0.7110871008474466
# Test Accuracy: 0.6618471525523754

# %% [markdown]
# That's a slight improvement :). Let's try a simpler less overfitted model.

# %%
# Instantiate a Random Forsest
forest_sklearn2 = RandomForestClassifier(n_estimators=100, max_depth=7, min_samples_split=400, min_samples_leaf=250, max_features="sqrt", bootstrap=True)
forest_sklearn2 = forest_sklearn2.fit(x_train, y_pred_train)

# Make predictions and test accuracy
predictions_train = forest_sklearn2.predict(x_train)
predictions_test = forest_sklearn2.predict(x_test)
print("Train Accuracy: "+str(accuracy_score(y_pred_train, predictions_train)))
print("Test Accuracy: "+str(accuracy_score(y_pred_test, predictions_test)))
# Out:
# Train Accuracy: 0.6710188885562166
# Test Accuracy: 0.662142224845087

# %% [markdown]
# Seems like accuracy kinda decreased. I'm going to run a quick GridSearch to see if we could improve this. Let's see if we can find the best hyperparameters :)

# %%
# This is going to take a long time, if you want to comment it out (I already did this myself and the results are in the models folder)
param_grid = {
    'n_estimators': [100, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [10, 20],
    'min_samples_leaf': [5, 10],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid,
    cv=5, 
    n_jobs=-1,
    verbose=4
)
grid_search.fit(x_train, y_pred_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.667 total time=  20.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.667 total time=  20.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.663 total time=  20.6s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.661 total time=  21.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.669 total time=  21.0s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.666 total time=  21.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.668 total time=  21.9s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.663 total time=  22.1s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.660 total time=  22.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.667 total time= 1.1min
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.667 total time=  22.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.662 total time= 1.1min
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.668 total time= 1.1min
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.661 total time= 1.1min
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.668 total time= 1.1min
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.667 total time=  23.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.668 total time=  24.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.662 total time=  24.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.666 total time= 1.2min
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.662 total time=  25.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.667 total time=  24.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.667 total time= 1.2min
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.663 total time= 1.2min
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.661 total time= 1.2min
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.668 total time= 1.2min
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.667 total time=  25.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.667 total time=  25.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.663 total time=  25.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.666 total time= 1.2min
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.668 total time= 1.2min
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.661 total time=  24.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.668 total time=  24.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.662 total time= 1.2min
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.665 total time=  18.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.661 total time= 1.2min
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.668 total time= 1.2min
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.666 total time=  18.6s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.660 total time=  18.3s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.660 total time=  18.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.666 total time= 1.2min
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.667 total time=  18.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.667 total time= 1.2min
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.662 total time= 1.2min
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.661 total time= 1.2min
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.667 total time= 1.2min
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.667 total time=  18.9s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.666 total time=  18.9s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.663 total time=  18.6s
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.666 total time=  56.2s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.666 total time=  56.4s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.662 total time=  56.9s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.660 total time=  19.5s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.668 total time=  19.5s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.660 total time=  56.6s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.668 total time=  56.5s
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.666 total time=  19.2s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.666 total time=  18.9s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.661 total time=  18.9s
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.666 total time=  57.5s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.659 total time=  19.1s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.667 total time=  18.8s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.666 total time=  57.6s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.661 total time=  57.3s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.659 total time=  57.2s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.667 total time=  57.1s
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.666 total time=  19.3s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.665 total time=  19.3s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.663 total time=  18.9s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.661 total time=  18.7s
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.666 total time=  56.5s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.666 total time=  19.2s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.667 total time=  57.7s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.661 total time=  57.4s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.661 total time=  57.6s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.667 total time=  57.2s
# [CV 1/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.667 total time=  57.0s
# [CV 2/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.666 total time=  56.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.670 total time=  43.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.670 total time=  43.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.664 total time=  43.5s
# [CV 3/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.661 total time=  57.0s
# [CV 4/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.659 total time=  57.0s
# [CV 5/5] END max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.668 total time=  57.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.665 total time=  44.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.670 total time=  44.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.670 total time=  44.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.670 total time=  43.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.664 total time=  43.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.664 total time=  44.3s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.670 total time=  43.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.671 total time= 2.2min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.671 total time= 2.2min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.663 total time= 2.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.665 total time= 2.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.670 total time=  44.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.670 total time=  44.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.664 total time=  44.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.665 total time=  44.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.670 total time=  44.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.666 total time= 2.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.665 total time= 2.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.670 total time=  44.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.670 total time=  45.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.663 total time=  45.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.665 total time=  44.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.671 total time= 2.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.670 total time=  44.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.663 total time= 2.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.667 total time= 2.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.669 total time= 2.2min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.669 total time=  33.7s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.671 total time=  33.7s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.663 total time=  33.9s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.665 total time=  34.2s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.669 total time=  34.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.672 total time= 2.2min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.669 total time= 2.2min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.663 total time= 2.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.664 total time= 2.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.669 total time= 2.2min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.672 total time= 1.7min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.672 total time=  34.0s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.668 total time=  34.3s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.663 total time=  34.0s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.669 total time= 1.7min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.663 total time= 1.7min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.662 total time=  34.6s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.664 total time= 1.7min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.669 total time= 1.7min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.668 total time=  34.7s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.669 total time=  34.0s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.669 total time=  33.9s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.664 total time=  33.9s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.664 total time=  34.3s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.669 total time=  34.1s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.671 total time= 1.7min
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.670 total time= 1.7min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.663 total time= 1.7min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.664 total time= 1.7min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.668 total time= 1.7min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.670 total time=  34.1s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.668 total time=  34.0s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.664 total time=  34.1s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.670 total time= 1.7min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.662 total time=  33.8s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.667 total time=  33.6s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.669 total time= 1.7min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.663 total time= 1.7min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.665 total time= 1.7min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.668 total time= 1.7min
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.671 total time=  58.3s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.671 total time= 1.7min
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.672 total time=  58.2s
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.663 total time=  58.5s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.669 total time= 1.7min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.662 total time= 1.7min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.665 total time= 1.7min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.670 total time= 1.7min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.663 total time=  59.1s
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.672 total time=  59.4s
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.670 total time=  58.5s
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.669 total time=  59.2s
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.665 total time=  58.3s
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.663 total time= 1.0min
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.671 total time= 1.0min
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.673 total time= 3.0min
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.670 total time= 3.0min
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.663 total time= 3.0min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.662 total time= 3.0min
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.672 total time= 3.0min
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.672 total time=  58.2s
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.669 total time=  58.1s
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.664 total time=  58.4s
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.673 total time= 3.0min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.665 total time=  57.1s
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.669 total time=  56.7s
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.671 total time= 3.0min
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.663 total time= 2.9min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.665 total time= 3.0min
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.671 total time= 2.9min
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.669 total time=  56.9s
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.671 total time=  57.1s
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.664 total time=  57.1s
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.672 total time= 2.9min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.665 total time=  56.7s
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.671 total time= 2.9min
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.671 total time=  56.5s
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.663 total time= 2.8min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.665 total time= 2.8min
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.670 total time= 2.8min
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.669 total time=  44.0s
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.669 total time=  44.0s
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.662 total time=  43.9s
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.662 total time=  43.9s
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.669 total time=  43.6s
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.672 total time= 2.8min
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.671 total time= 2.8min
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.664 total time= 2.8min
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.665 total time= 2.8min
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.670 total time= 2.8min
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.669 total time=  44.1s
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.668 total time=  44.4s
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.672 total time= 2.2min
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.664 total time=  44.3s
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.663 total time= 2.2min
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.666 total time= 2.2min
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.664 total time=  44.8s
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100;, score=0.672 total time=  45.4s
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=0.671 total time= 2.2min
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.668 total time=  43.3s
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.667 total time=  43.8s
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.665 total time=  43.7s
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.664 total time=  43.8s
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.669 total time=  44.3s
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.673 total time= 2.2min
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.671 total time= 2.2min
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.664 total time= 2.2min
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.664 total time= 2.2min
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=0.671 total time= 2.2min
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.670 total time=  45.0s
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.669 total time=  44.3s
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.662 total time=  44.0s
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.674 total time= 2.2min
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.665 total time=  44.6s
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100;, score=0.670 total time=  44.2s
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.664 total time= 2.2min
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.660 total time= 2.2min
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=0.670 total time= 2.2min
# [CV 1/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.672 total time= 2.0min
# [CV 2/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.670 total time= 2.0min
# [CV 3/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.664 total time= 1.9min
# [CV 4/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.664 total time= 1.8min
# [CV 5/5] END max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300;, score=0.672 total time= 1.7min
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [5, 10],
#                          'min_samples_split': [10, 20],
#                          'n_estimators': [100, 300]},
#              verbose=4)

# %%
# Best parameters
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)

# Instantiate a Random Forsest
best_forest_model = RandomForestClassifier(max_depth=15, max_features='log2', min_samples_leaf=5, min_samples_split=20, n_estimators=300)
best_forest_model = best_forest_model.fit(x_train, y_pred_train)

# Make predictions and test accuracy
predictions_train = best_forest_model.predict(x_train)
predictions_test = best_forest_model.predict(x_test)
print("Train Accuracy: "+str(accuracy_score(y_pred_train, predictions_train)))
print("Test Accuracy: "+str(accuracy_score(y_pred_test, predictions_test)))
# Out:
# Best Parameters: {'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 20, 'n_estimators': 300}
# Best Score: 0.6684674689234912
# Train Accuracy: 0.7993074629974355
# Test Accuracy: 0.6611094718205961

# %% [markdown]
# The gridSearchCV wasn't that successful, since the test accuracy was actually 0.6611. Let's train an XGBoost model and see if it does better.

# %% [markdown]
# ### Train XGBoost Algorithm

# %% [markdown]
# Let's try with XGBoost and see if we can get better results.

# %%
# Instantiate an XGBoost Classifier
xgb_model = XGBClassifier(n_estimators=200, max_depth=10, learning_rate=0.1, subsample=0.8, colsample_bytree=0.7)

# Train the model
xgb_model.fit(x_train, reverse_mapper(y_pred_train))

# Make predictions
predictions_train = xgb_model.predict(x_train)
predictions_test = xgb_model.predict(x_test)

# Calculate accuracy
print("Train Accuracy: " + str(accuracy_score(reverse_mapper(y_pred_train), predictions_train)))
print("Test Accuracy: " + str(accuracy_score(reverse_mapper(y_pred_test), predictions_test)))
# Out:
# Train Accuracy: 0.9742381442091149
# Test Accuracy: 0.6513720861611094

# %%
# Sorting by importance in descending order
sorted_mapped_results = sorted(
    list(zip(final_dataset.columns[:-1], list(xgb_model.feature_importances_))),
    key=lambda x: x[1], 
    reverse=True
)

# Extracting sorted labels and their importances
sorted_labels = [label for label, importance in sorted_mapped_results]
sorted_importances = [importance for _, importance in sorted_mapped_results]

# Displaying results
for label, importance in sorted_mapped_results:
    print(f"{label}: {importance:.4f}")
# Out:
# ELO_DIFF: 0.0843
# ELO_SURFACE_DIFF: 0.0429
# BEST_OF: 0.0204
# ATP_RANK_DIFF: 0.0189
# AGE_DIFF: 0.0161
# WIN_LAST_25_DIFF: 0.0155
# P_2ND_WON_LAST_100_DIFF: 0.0154
# P_1ST_WON_LAST_10_DIFF: 0.0142
# ATP_POINTS_DIFF: 0.0139
# P_ACE_LAST_5_DIFF: 0.0138
# P_1ST_WON_LAST_3_DIFF: 0.0138
# ELO_GRAD_LAST_200_DIFF: 0.0137
# H2H_SURFACE_DIFF: 0.0137
# P_1ST_WON_LAST_25_DIFF: 0.0136
# P_2ND_WON_LAST_200_DIFF: 0.0136
# ELO_GRAD_LAST_50_DIFF: 0.0136
# P_ACE_LAST_50_DIFF: 0.0136
# ELO_GRAD_LAST_100_DIFF: 0.0135
# H2H_DIFF: 0.0135
# WIN_LAST_200_DIFF: 0.0135
# P_1ST_WON_LAST_5_DIFF: 0.0135
# P_2ND_WON_LAST_25_DIFF: 0.0135
# P_2ND_WON_LAST_10_DIFF: 0.0135
# P_DF_LAST_200_DIFF: 0.0135
# P_1ST_WON_LAST_50_DIFF: 0.0135
# P_1ST_IN_LAST_3_DIFF: 0.0134
# P_1ST_IN_LAST_50_DIFF: 0.0134
# P_ACE_LAST_25_DIFF: 0.0134
# P_1ST_WON_LAST_100_DIFF: 0.0134
# P_BP_SAVED_LAST_50_DIFF: 0.0133
# P_2ND_WON_LAST_3_DIFF: 0.0133
# N_GAMES_DIFF: 0.0133
# P_DF_LAST_50_DIFF: 0.0133
# P_ACE_LAST_200_DIFF: 0.0132
# P_1ST_IN_LAST_200_DIFF: 0.0132
# P_DF_LAST_25_DIFF: 0.0132
# P_BP_SAVED_LAST_100_DIFF: 0.0132
# DRAW_SIZE: 0.0132
# P_1ST_WON_LAST_200_DIFF: 0.0132
# P_DF_LAST_10_DIFF: 0.0131
# P_2ND_WON_LAST_50_DIFF: 0.0131
# P_1ST_IN_LAST_5_DIFF: 0.0131
# P_BP_SAVED_LAST_5_DIFF: 0.0130
# WIN_LAST_100_DIFF: 0.0129
# WIN_LAST_3_DIFF: 0.0129
# P_BP_SAVED_LAST_200_DIFF: 0.0129
# P_1ST_IN_LAST_25_DIFF: 0.0129
# P_BP_SAVED_LAST_25_DIFF: 0.0129
# P_DF_LAST_3_DIFF: 0.0129
# P_BP_SAVED_LAST_3_DIFF: 0.0128
# P_DF_LAST_5_DIFF: 0.0128
# P_2ND_WON_LAST_5_DIFF: 0.0128
# P_ACE_LAST_10_DIFF: 0.0128
# ELO_GRAD_LAST_10_DIFF: 0.0127
# P_ACE_LAST_100_DIFF: 0.0127
# P_ACE_LAST_3_DIFF: 0.0127
# P_1ST_IN_LAST_10_DIFF: 0.0127
# P_BP_SAVED_LAST_10_DIFF: 0.0126
# ELO_GRAD_LAST_25_DIFF: 0.0126
# ELO_GRAD_LAST_5_DIFF: 0.0125
# WIN_LAST_50_DIFF: 0.0125
# P_DF_LAST_100_DIFF: 0.0123
# ELO_GRAD_LAST_3_DIFF: 0.0123
# WIN_LAST_5_DIFF: 0.0123
# WIN_LAST_10_DIFF: 0.0122
# HEIGHT_DIFF: 0.0121
# P_1ST_IN_LAST_100_DIFF: 0.0119

# %% [markdown]
# Okay this is overfitting significantly, let's try regularization.

# %%
# Instantiate an XGBoost Classifier
xgb_model = XGBClassifier(
    n_estimators=100, 
    max_depth=5, 
    learning_rate=0.05, 
    subsample=0.7, 
    colsample_bytree=0.6,
    reg_alpha=0.1,
    reg_lambda=1.0
)

# Train the model
xgb_model.fit(x_train, reverse_mapper(y_pred_train))

# Make predictions
predictions_train = xgb_model.predict(x_train)
predictions_test = xgb_model.predict(x_test)

# Calculate accuracy
print("Train Accuracy: " + str(accuracy_score(reverse_mapper(y_pred_train), predictions_train)))
print("Test Accuracy: " + str(accuracy_score(reverse_mapper(y_pred_test), predictions_test)))
# Out:
# Train Accuracy: 0.681524102110155
# Test Accuracy: 0.6690764237238124

# %%
xgb_model.save_model("./models/xgb_model.json")

# %% [markdown]
# That's slightly better. Let's run a gridsearch to really make sure.

# %%
# Define parameter grid with all specified parameters
param_grid = {
    'n_estimators': [100, 300],
    'max_depth': [5, 10],
    'learning_rate': [0.01, 0.05],
    'subsample': [0.7],
    'colsample_bytree': [0.6],
    'reg_alpha': [0.1, 0.5],
    'reg_lambda': [0.5, 1.0]
}

# Instantiate an XGBoost Classifier
xgb_model = XGBClassifier()

# Perform GridSearchCV
grid_search = GridSearchCV(
    estimator=xgb_model, 
    param_grid=param_grid, 
    scoring='accuracy', 
    cv=5, 
    verbose=3, 
    n_jobs=-1
)
grid_search.fit(x_train, reverse_mapper(y_pred_train))
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=   2.9s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=   3.0s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=   3.0s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=   3.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   3.1s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=   3.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=   3.1s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=   3.2s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=   2.1s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.670 total time=   2.3s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=   2.5s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   2.7s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=   2.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=   2.7s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=   2.7s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=   3.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=   3.0s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=   3.2s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=   3.1s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.670 total time=   3.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=   7.7s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=   7.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=   7.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=   8.1s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   8.0s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.671 total time=   8.4s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=   8.7s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=   8.6s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=   8.8s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=   8.7s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=   9.1s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=   8.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=   8.9s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=   9.0s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   9.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.671 total time=   9.5s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=   9.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.667 total time=  10.0s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=  10.7s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.671 total time=  10.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.671 total time=  18.7s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=  19.1s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=  19.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=  20.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=  20.9s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.670 total time=  21.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=  20.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=  21.5s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=  24.1s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=  25.0s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=  24.6s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.671 total time=  23.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=  24.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=  24.9s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=  24.3s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.671 total time=  24.1s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=  22.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=  23.1s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=  22.9s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=  23.2s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=  52.8s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=  51.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=  53.1s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=  52.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.675 total time=  52.2s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.674 total time=  52.2s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=  51.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=  50.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=  49.1s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=  48.3s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=  49.4s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=  49.3s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.667 total time=  48.9s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.667 total time=  49.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=  48.0s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=  48.7s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.674 total time=   7.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=   4.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.675 total time=   7.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=   7.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   4.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.675 total time=   4.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.667 total time=   4.0s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.674 total time=   6.9s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=   4.2s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=   4.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.675 total time=   4.3s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.676 total time=   4.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.667 total time=   4.5s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.667 total time=   4.2s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   4.4s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=   4.5s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.675 total time=   4.6s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=   4.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=   4.7s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=   4.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.674 total time=  50.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.666 total time=  48.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=  48.7s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.673 total time=   9.9s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.676 total time=   9.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.667 total time=   9.3s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.674 total time=  51.8s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=   9.2s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.671 total time=  11.6s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=  11.8s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=   8.5s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.675 total time=  11.8s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.667 total time=   8.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=   8.9s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   8.9s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.674 total time=   8.9s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=   8.9s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=   9.1s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.672 total time=   9.2s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.672 total time=   9.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.674 total time=   9.3s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.665 total time=   9.4s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.669 total time=   9.7s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=5, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=   9.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.668 total time=  15.0s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=  15.8s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.660 total time=  15.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.663 total time=  15.9s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=  15.8s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=  15.7s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.673 total time=  16.0s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.663 total time=  16.1s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.664 total time=  16.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.668 total time=  16.4s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.670 total time=  16.8s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.671 total time=  17.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.664 total time=  16.5s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.660 total time=  16.3s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.669 total time=  15.9s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.670 total time=  16.1s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.669 total time=  18.5s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.664 total time=  18.7s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.661 total time=  18.7s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.669 total time=  19.1s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.661 total time=  37.4s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.663 total time=  36.6s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.661 total time=  35.9s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.657 total time=  34.6s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7;, score=0.665 total time=  33.9s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.661 total time=  34.2s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.669 total time=  34.6s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.659 total time=  34.2s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.657 total time=  35.8s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.1, reg_lambda=1.0, subsample=0.7;, score=0.663 total time=  36.2s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=  38.3s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=  37.3s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.658 total time=  37.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.666 total time=  35.2s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7;, score=0.657 total time=  37.5s
# [CV 1/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.664 total time=  36.2s
# [CV 2/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.667 total time=  27.2s
# [CV 3/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.660 total time=  26.1s
# [CV 4/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.659 total time=  24.5s
# [CV 5/5] END colsample_bytree=0.6, learning_rate=0.05, max_depth=10, n_estimators=300, reg_alpha=0.5, reg_lambda=1.0, subsample=0.7;, score=0.669 total time=  23.1s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6],
#                          'learning_rate': [0.01, 0.05], 'max_depth': [5, 10],
#                          'n_estimators': [100, 300], 'reg_alpha': [0.1, 0.5],
#                          'reg_lambda': [0.5, 1.0], 'subsample': [0.7]},
#              scoring='accuracy', verbose=3)

# %%
# Best parameters
print("Best Parameters:", grid_search.best_params_)

# Train the best model
best_xgb_model = grid_search.best_estimator_

# Make predictions
predictions_train = best_xgb_model.predict(x_train)
predictions_test = best_xgb_model.predict(x_test)

# Calculate accuracy
print("Train Accuracy:", accuracy_score(reverse_mapper(y_pred_train), predictions_train))
print("Test Accuracy:", accuracy_score(reverse_mapper(y_pred_test), predictions_test))
# Out:
# Best Parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.5, 'reg_lambda': 0.5, 'subsample': 0.7}
# Train Accuracy: 0.6818365248180789
# Test Accuracy: 0.6672322218943642

# %%
best_xgb_model = grid_search.best_estimator_
best_xgb_model.save_model("./models/best_xgb_model.json")

# %% [markdown]
# ### Train Neural Net

# %%
# Normalize the data
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# Define the neural network
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(x_train_scaled.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train_scaled, reverse_mapper(y_pred_train), epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate on test set
train_loss, train_acc = model.evaluate(x_train_scaled, reverse_mapper(y_pred_train), verbose=0)
test_loss, test_acc = model.evaluate(X_test_scaled, reverse_mapper(y_pred_test), verbose=0)

print(f"Train Accuracy: {train_acc}")
print(f"Test Accuracy: {test_acc}")
# Out:
# /opt/homebrew/anaconda3/envs/neuralNets/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 2s 664us/step - accuracy: 0.6522 - loss: 0.6208 - val_accuracy: 0.6737 - val_loss: 0.6040
# Epoch 2/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.6687 - loss: 0.6013 - val_accuracy: 0.6722 - val_loss: 0.6017
# Epoch 3/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.6748 - loss: 0.5997 - val_accuracy: 0.6711 - val_loss: 0.6019
# Epoch 4/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.6710 - loss: 0.5993 - val_accuracy: 0.6705 - val_loss: 0.6028
# Epoch 5/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 601us/step - accuracy: 0.6759 - loss: 0.5942 - val_accuracy: 0.6701 - val_loss: 0.6025
# Epoch 6/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 599us/step - accuracy: 0.6762 - loss: 0.5937 - val_accuracy: 0.6689 - val_loss: 0.6056
# Epoch 7/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 600us/step - accuracy: 0.6800 - loss: 0.5916 - val_accuracy: 0.6691 - val_loss: 0.6033
# Epoch 8/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - accuracy: 0.6825 - loss: 0.5870 - val_accuracy: 0.6685 - val_loss: 0.6054
# Epoch 9/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.6853 - loss: 0.5860 - val_accuracy: 0.6637 - val_loss: 0.6105
# Epoch 10/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.6828 - loss: 0.5875 - val_accuracy: 0.6677 - val_loss: 0.6107
# Epoch 11/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.6871 - loss: 0.5818 - val_accuracy: 0.6677 - val_loss: 0.6092
# Epoch 12/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.6895 - loss: 0.5783 - val_accuracy: 0.6671 - val_loss: 0.6131
# Epoch 13/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - accuracy: 0.6897 - loss: 0.5796 - val_accuracy: 0.6650 - val_loss: 0.6131
# Epoch 14/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 599us/step - accuracy: 0.6928 - loss: 0.5740 - val_accuracy: 0.6655 - val_loss: 0.6169
# Epoch 15/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.6943 - loss: 0.5756 - val_accuracy: 0.6639 - val_loss: 0.6173
# Epoch 16/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.6953 - loss: 0.5728 - val_accuracy: 0.6676 - val_loss: 0.6232
# Epoch 17/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.6990 - loss: 0.5693 - val_accuracy: 0.6616 - val_loss: 0.6254
# Epoch 18/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 599us/step - accuracy: 0.6991 - loss: 0.5691 - val_accuracy: 0.6628 - val_loss: 0.6281
# Epoch 19/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - accuracy: 0.7006 - loss: 0.5672 - val_accuracy: 0.6602 - val_loss: 0.6237
# Epoch 20/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 600us/step - accuracy: 0.7006 - loss: 0.5645 - val_accuracy: 0.6590 - val_loss: 0.6323
# Epoch 21/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.7067 - loss: 0.5625 - val_accuracy: 0.6576 - val_loss: 0.6302
# Epoch 22/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.7073 - loss: 0.5579 - val_accuracy: 0.6570 - val_loss: 0.6325
# Epoch 23/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 601us/step - accuracy: 0.7103 - loss: 0.5546 - val_accuracy: 0.6583 - val_loss: 0.6335
# Epoch 24/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.7089 - loss: 0.5563 - val_accuracy: 0.6582 - val_loss: 0.6328
# Epoch 25/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 599us/step - accuracy: 0.7087 - loss: 0.5558 - val_accuracy: 0.6583 - val_loss: 0.6393
# Epoch 26/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.7103 - loss: 0.5539 - val_accuracy: 0.6531 - val_loss: 0.6412
# Epoch 27/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.7112 - loss: 0.5530 - val_accuracy: 0.6543 - val_loss: 0.6392
# Epoch 28/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.7122 - loss: 0.5526 - val_accuracy: 0.6543 - val_loss: 0.6471
# Epoch 29/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.7147 - loss: 0.5458 - val_accuracy: 0.6568 - val_loss: 0.6458
# Epoch 30/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 733us/step - accuracy: 0.7130 - loss: 0.5516 - val_accuracy: 0.6526 - val_loss: 0.6538
# Epoch 31/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.7161 - loss: 0.5477 - val_accuracy: 0.6476 - val_loss: 0.6531
# Epoch 32/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 593us/step - accuracy: 0.7191 - loss: 0.5398 - val_accuracy: 0.6550 - val_loss: 0.6499
# Epoch 33/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.7189 - loss: 0.5442 - val_accuracy: 0.6509 - val_loss: 0.6550
# Epoch 34/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 618us/step - accuracy: 0.7207 - loss: 0.5419 - val_accuracy: 0.6529 - val_loss: 0.6593
# Epoch 35/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 608us/step - accuracy: 0.7233 - loss: 0.5368 - val_accuracy: 0.6469 - val_loss: 0.6512
# Epoch 36/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - accuracy: 0.7212 - loss: 0.5399 - val_accuracy: 0.6494 - val_loss: 0.6625
# Epoch 37/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 592us/step - accuracy: 0.7249 - loss: 0.5354 - val_accuracy: 0.6474 - val_loss: 0.6665
# Epoch 38/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 592us/step - accuracy: 0.7262 - loss: 0.5329 - val_accuracy: 0.6475 - val_loss: 0.6653
# Epoch 39/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.7265 - loss: 0.5336 - val_accuracy: 0.6493 - val_loss: 0.6703
# Epoch 40/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 604us/step - accuracy: 0.7230 - loss: 0.5347 - val_accuracy: 0.6494 - val_loss: 0.6761
# Epoch 41/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 604us/step - accuracy: 0.7240 - loss: 0.5297 - val_accuracy: 0.6425 - val_loss: 0.6646
# Epoch 42/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step - accuracy: 0.7274 - loss: 0.5321 - val_accuracy: 0.6446 - val_loss: 0.6716
# Epoch 43/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - accuracy: 0.7257 - loss: 0.5324 - val_accuracy: 0.6384 - val_loss: 0.6724
# Epoch 44/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.7306 - loss: 0.5265 - val_accuracy: 0.6431 - val_loss: 0.6725
# Epoch 45/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 596us/step - accuracy: 0.7282 - loss: 0.5287 - val_accuracy: 0.6480 - val_loss: 0.6792
# Epoch 46/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 592us/step - accuracy: 0.7298 - loss: 0.5295 - val_accuracy: 0.6475 - val_loss: 0.6793
# Epoch 47/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.7320 - loss: 0.5229 - val_accuracy: 0.6428 - val_loss: 0.6787
# Epoch 48/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 594us/step - accuracy: 0.7297 - loss: 0.5262 - val_accuracy: 0.6459 - val_loss: 0.6829
# Epoch 49/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 595us/step - accuracy: 0.7329 - loss: 0.5199 - val_accuracy: 0.6458 - val_loss: 0.6826
# Epoch 50/50
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 590us/step - accuracy: 0.7300 - loss: 0.5243 - val_accuracy: 0.6470 - val_loss: 0.6911
# Train Accuracy: 0.7187544703483582
# Test Accuracy: 0.6383889317512512

# %% [markdown]
# The neural net wasn't the best result. I could try to optimize it, but since the video was mostly about random forest/decision trees, I focused more on that.

# %% [markdown]
# I expored the best result from the GridSearch and now we can use it to predict stuff :).

# %% [markdown]
# See the next notebook (3.Predict.ipynb) for this.
